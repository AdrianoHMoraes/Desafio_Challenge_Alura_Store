# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja4.head(20)
# Out:
#                      Produto   Categoria do Produto    Preço       Frete  \
# 0                Lava louças       eletrodomesticos  1446.46   74.604083
# 1                   Cama box                 moveis   631.70   33.919251
# 2           Bola de basquete        esporte e lazer    31.54    0.000000
# 3        Modelagem preditiva                 livros    76.93    1.680730
# 4             Fone de ouvido            eletronicos   185.14    7.442587
# 5                  Geladeira       eletrodomesticos  2122.48  110.600114
# 6                   Guitarra  instrumentos musicais   834.88   50.696784
# 7                    Headset            eletronicos   125.96   15.801377
# 8           Celular Plus X42            eletronicos  3118.72  163.646897
# 9                     Cômoda                 moveis   364.39   29.259964
# 10          Bola de basquete        esporte e lazer    90.72    7.994383
# 11               Boneca bebê             brinquedos    63.30    0.000000
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
Faturamento_loja1 = loja['Preço'].sum().round(2)
Faturamento_loja1
# Out:
# np.float64(1534509.12)

# %%
Faturamento_loja2 = loja2['Preço'].sum().round(2)
Faturamento_loja2
# Out:
# np.float64(1488459.06)

# %%
Faturamento_loja3 = loja3['Preço'].sum().round(2)
Faturamento_loja3
# Out:
# np.float64(1464025.03)

# %%
Faturamento_loja4 = loja4['Preço'].sum().round(2)
Faturamento_loja4
# Out:
# np.float64(1384497.58)

# %%
Faturamento_lojas = pd.DataFrame([Faturamento_loja4,Faturamento_loja3,Faturamento_loja2,Faturamento_loja1],columns=['Faturamento'],index=['Loja 1','Loja 2','Loja 3','Loja 4'])
Faturamento_lojas
# Out:
#         Faturamento
# Loja 1   1384497.58
# Loja 2   1464025.03
# Loja 3   1488459.06
# Loja 4   1534509.12

# %%
Faturamento_total_geral = Faturamento_lojas['Faturamento'].sum()
Faturamento_total_geral
# Out:
# np.float64(5871490.79)

# %%
Faturamento_lojas['Percentual (%)'] = (Faturamento_lojas['Faturamento'] / Faturamento_total_geral) * 100
Faturamento_lojas = Faturamento_lojas.round(2)
Faturamento_lojas.sort_values(by='Faturamento', ascending=False)
# Out:
#         Faturamento  Percentual (%)
# Loja 4   1534509.12           26.13
# Loja 3   1488459.06           25.35
# Loja 2   1464025.03           24.93
# Loja 1   1384497.58           23.58
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Faturamento'].plot(kind='hist', bins=20, title='Faturamento')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Percentual (%)'].plot(kind='hist', bins=20, title='Percentual (%)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Faturamento', y='Percentual (%)', s=32, alpha=.8)
# ...

# %%
from matplotlib import pyplot as plt
_df_3['Faturamento'].plot(kind='line', figsize=(8, 4), title='Faturamento')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # 2. Vendas por Categoria

# %%
Total_categorias_loja1 = loja.groupby('Categoria do Produto')['Categoria do Produto'].count().round(2).sort_values(ascending=False)
Total_categorias_loja1
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: Categoria do Produto, dtype: int64

# %%
percentual_categorias_loja1 = loja['Categoria do Produto'].value_counts(normalize=True) * 100
percentual_categorias_loja1.round(2)
# Out:
# Categoria do Produto
# moveis                   19.71
# eletronicos              18.99
# brinquedos               13.73
# eletrodomesticos         13.23
# esporte e lazer          12.04
# instrumentos musicais     7.72
# livros                    7.33
# utilidades domesticas     7.25
# Name: proportion, dtype: float64

# %%
Total_categorias_loja2 = loja2.groupby('Categoria do Produto')['Categoria do Produto'].count().round(2).sort_values(ascending=False)
Total_categorias_loja2
# Out:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: Categoria do Produto, dtype: int64

# %%
percentual_categorias_loja2 = loja2['Categoria do Produto'].value_counts(normalize=True) * 100
percentual_categorias_loja2.round(2)
# Out:
# Categoria do Produto
# moveis                   18.74
# eletronicos              17.89
# brinquedos               13.27
# eletrodomesticos         12.93
# esporte e lazer          11.66
# instrumentos musicais     9.50
# livros                    8.35
# utilidades domesticas     7.67
# Name: proportion, dtype: float64

# %%
Total_categorias_loja3 = loja3.groupby('Categoria do Produto')['Categoria do Produto'].count().round(2).sort_values(ascending=False)
Total_categorias_loja3
# Out:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: Categoria do Produto, dtype: int64

# %%
percentual_categorias_loja3 = loja3['Categoria do Produto'].value_counts(normalize=True) * 100
percentual_categorias_loja3.round(2)
# Out:
# Categoria do Produto
# moveis                   21.15
# eletronicos              19.12
# brinquedos               13.35
# eletrodomesticos         11.78
# esporte e lazer          11.74
# livros                    7.84
# instrumentos musicais     7.50
# utilidades domesticas     7.50
# Name: proportion, dtype: float64

# %%
Total_categorias_loja4 = loja4.groupby('Categoria do Produto')['Categoria do Produto'].count().round(2).sort_values(ascending=False)
Total_categorias_loja4
# Out:
# Categoria do Produto
# moveis                   480
# eletronicos              451
# brinquedos               338
# esporte e lazer          277
# eletrodomesticos         254
# utilidades domesticas    201
# livros                   187
# instrumentos musicais    170
# Name: Categoria do Produto, dtype: int64

# %%
percentual_categorias_loja4 = loja4['Categoria do Produto'].value_counts(normalize=True) * 100
percentual_categorias_loja4.round(2)
# Out:
# Categoria do Produto
# moveis                   20.36
# eletronicos              19.13
# brinquedos               14.33
# esporte e lazer          11.75
# eletrodomesticos         10.77
# utilidades domesticas     8.52
# livros                    7.93
# instrumentos musicais     7.21
# Name: proportion, dtype: float64

# %%
df_percentual_combinado = pd.DataFrame({
    'Loja': percentual_categorias_loja1,
    'Loja2': percentual_categorias_loja2,
    'Loja3': percentual_categorias_loja3,
    'Loja4': percentual_categorias_loja4})
df_percentual_combinado.round(2).sort_values(by='Loja', ascending=False)
# Out:
#                         Loja  Loja2  Loja3  Loja4
# Categoria do Produto
# moveis                 19.71  18.74  21.15  20.36
# eletronicos            18.99  17.89  19.12  19.13
# brinquedos             13.73  13.27  13.35  14.33
# eletrodomesticos       13.23  12.93  11.78  10.77
# esporte e lazer        12.04  11.66  11.74  11.75
# instrumentos musicais   7.72   9.50   7.50   7.21
# livros                  7.33   8.35   7.84   7.93
# utilidades domesticas   7.25   7.67   7.50   8.52

# %%
cores_personalizadas = ['#FF5733', '#33FF57', '#3357FF', '#FF33A1']
df_percentual_combinado.plot(kind='line', figsize=(14,4), color=(cores_personalizadas))
# Out:
# <Axes: xlabel='Categoria do Produto'>

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_avaliacao_loja1 = loja['Avaliação da compra'].mean().round(2)
media_avaliacao_loja1
# Out:
# np.float64(3.98)

# %%
media_avaliacao_loja2 = loja2['Avaliação da compra'].mean().round(2)
media_avaliacao_loja2
# Out:
# np.float64(4.04)

# %%
media_avaliacao_loja3 = loja3['Avaliação da compra'].mean().round(2)
media_avaliacao_loja3
# Out:
# np.float64(4.05)

# %%
media_avaliacao_loja4 = loja4['Avaliação da compra'].mean().round(2)

# %%
medias_avaliacao_lojas = pd.DataFrame([media_avaliacao_loja4,media_avaliacao_loja3,media_avaliacao_loja2,media_avaliacao_loja1],columns=['Avaliação da compra'],index=['Loja 1','Loja 2','Loja 3','Loja 4'])
medias_avaliacao_lojas
# Out:
#         Avaliação da compra
# Loja 1                 4.00
# Loja 2                 4.05
# Loja 3                 4.04
# Loja 4                 3.98

# %%
medias_avaliacao_lojas.plot(kind='line', figsize=(14,4), color='blue')
# Out:
# <Axes: >

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
Vendas_Produtos_loja1 = loja.groupby('Produto')['Produto'].count().round(2).sort_values(ascending=False)
Vendas_Produtos_loja1
# Out:
# Produto
# TV Led UHD 4K                  60
# Micro-ondas                    60
# Guarda roupas                  60
# Secadora de roupas             58
# Blocos de montar               56
# Cômoda                         56
# Bola de basquete               55
# Bicicleta                      54
# Copo térmico                   54
# Geladeira                      54
# Impressora                     54
# Bateria                        53
# Faqueiro                       52
# Carrinho controle remoto       52
# Modelagem preditiva            51
# Fone de ouvido                 50
# Celular Plus X42               49
# Xadrez de madeira              49
# Lava louças                    48
# Lavadora de roupas             47
# Guitarra                       47
# Cadeira de escritório          46
# Sofá retrátil                  46
# Violão                         46
# Fogão                          45
# Smart TV                       44
# Mesa de centro                 44
# ...

# %%
Vendas_Produtos_loja1.head(5)
# Out:
# Produto
# TV Led UHD 4K         60
# Micro-ondas           60
# Guarda roupas         60
# Secadora de roupas    58
# Blocos de montar      56
# Name: Produto, dtype: int64

# %%
Mais_vendidos_loja1 = Vendas_Produtos_loja1.head(5)
Mais_vendidos_loja1
# Out:
# Produto
# TV Led UHD 4K         60
# Micro-ondas           60
# Guarda roupas         60
# Secadora de roupas    58
# Blocos de montar      56
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja1.tail(5)
# Out:
# Produto
# Ciência de dados com python    39
# Pandeiro                       36
# Panela de pressão              35
# Celular ABXY                   33
# Headset                        33
# Name: Produto, dtype: int64

# %%
Menos_vendidos_loja1 = Vendas_Produtos_loja1.tail(5)
Menos_vendidos_loja1
# Out:
# Produto
# Ciência de dados com python    39
# Pandeiro                       36
# Panela de pressão              35
# Celular ABXY                   33
# Headset                        33
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja2 = loja2.groupby('Produto')['Produto'].count().round(2).sort_values(ascending=False)
Vendas_Produtos_loja2
# Out:
# Produto
# Iniciando em programação       65
# Micro-ondas                    62
# Bateria                        61
# Violão                         58
# Pandeiro                       58
# Secadora de roupas             57
# Celular Plus X42               55
# Guarda roupas                  54
# Blocos de montar               54
# Jogo de panelas                52
# Corda de pular                 50
# Geladeira                      49
# Cadeira de escritório          49
# Lavadora de roupas             49
# Boneca bebê                    48
# Carrinho controle remoto       47
# Cama box                       47
# Guitarra                       47
# Copo térmico                   47
# Lava louças                    46
# Bola de vôlei                  46
# Jogo de copos                  46
# Modelagem preditiva            46
# Xadrez de madeira              45
# Kit banquetas                  45
# Cama king                      45
# Cubo mágico 8x8                45
# ...

# %%
Vendas_Produtos_loja2.head(5)
# Out:
# Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
# Name: Produto, dtype: int64

# %%
Mais_vendidos_loja2 = Vendas_Produtos_loja2.head(5)
Mais_vendidos_loja2
# Out:
# Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja2.tail(5)
# Out:
# Produto
# Fone de ouvido       37
# Poltrona             35
# Impressora           34
# Mesa de jantar       34
# Jogo de tabuleiro    32
# Name: Produto, dtype: int64

# %%
Menos_vendidos_loja2 = Vendas_Produtos_loja2.tail(5)
Menos_vendidos_loja2
# Out:
# Produto
# Fone de ouvido       37
# Poltrona             35
# Impressora           34
# Mesa de jantar       34
# Jogo de tabuleiro    32
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja3 = loja3.groupby('Produto')['Produto'].count().round(2).sort_values(ascending=False)
Vendas_Produtos_loja3
# Out:
# Produto
# Kit banquetas                  57
# Mesa de jantar                 56
# Cama king                      56
# Cômoda                         55
# Jogo de panelas                55
# Smart TV                       54
# Fogão                          53
# Modelagem preditiva            53
# Corda de pular                 53
# Bicicleta                      52
# Carrinho controle remoto       52
# Jogo de tabuleiro              52
# Lava louças                    52
# Pandeiro                       51
# Bola de basquete               50
# Geladeira                      50
# Impressora                     50
# Guarda roupas                  49
# Bola de vôlei                  48
# Tablet ABXY                    48
# Panela de pressão              47
# Violão                         47
# Poltrona                       47
# Xadrez de madeira              47
# Smartwatch                     46
# Iniciando em programação       46
# Dinossauro Rex                 46
# ...

# %%
Vendas_Produtos_loja3.head(5)
# Out:
# Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# Cômoda             55
# Jogo de panelas    55
# Name: Produto, dtype: int64

# %%
Mais_vendidos_loja3 = Vendas_Produtos_loja3.head(5)
Mais_vendidos_loja3
# Out:
# Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# Cômoda             55
# Jogo de panelas    55
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja3.tail(5)
# Out:
# Produto
# Copo térmico        38
# Micro-ondas         36
# Jogo de copos       36
# Mochila             36
# Blocos de montar    35
# Name: Produto, dtype: int64

# %%
Menos_vendidos_loja3 = Vendas_Produtos_loja3.tail(5)
Menos_vendidos_loja3
# Out:
# Produto
# Copo térmico        38
# Micro-ondas         36
# Jogo de copos       36
# Mochila             36
# Blocos de montar    35
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja4 = loja4.groupby('Produto')['Produto'].count().round(2).sort_values(ascending=False)
Vendas_Produtos_loja4
# Out:
# Produto
# Cama box                       62
# Faqueiro                       59
# Cama king                      56
# Dashboards com Power BI        56
# Cômoda                         55
# Mesa de jantar                 55
# Carrinho controle remoto       55
# Blocos de montar               54
# Smart TV                       54
# Pandeiro                       52
# Assistente virtual             50
# Bola de basquete               50
# Jogo de panelas                50
# Impressora                     50
# Modelagem preditiva            50
# Copo térmico                   48
# Bateria                        48
# Celular Plus X42               48
# Bola de vôlei                  48
# Micro-ondas                    48
# Jogo de tabuleiro              48
# Boneca bebê                    48
# Fogão                          47
# Sofá retrátil                  47
# Cubo mágico 8x8                47
# Dinossauro Rex                 47
# Jogo de copos                  46
# ...

# %%
Vendas_Produtos_loja4.head(5)
# Out:
# Produto
# Cama box                   62
# Faqueiro                   59
# Cama king                  56
# Dashboards com Power BI    56
# Cômoda                     55
# Name: Produto, dtype: int64

# %%
Mais_vendidos_loja4 = Vendas_Produtos_loja4.head(5)
Mais_vendidos_loja4
# Out:
# Produto
# Cama box                   62
# Faqueiro                   59
# Cama king                  56
# Dashboards com Power BI    56
# Cômoda                     55
# Name: Produto, dtype: int64

# %%
Vendas_Produtos_loja4.tail(5)
# Out:
# Produto
# Geladeira             38
# Lavadora de roupas    38
# Violão                37
# Guarda roupas         34
# Guitarra              33
# Name: Produto, dtype: int64

# %%
Menos_vendidos_loja4 = Vendas_Produtos_loja4.tail(5)
Menos_vendidos_loja4
# Out:
# Produto
# Geladeira             38
# Lavadora de roupas    38
# Violão                37
# Guarda roupas         34
# Guitarra              33
# Name: Produto, dtype: int64

# %%
df_Maiores_Vendas_combinado = pd.DataFrame({
    'Loja': Mais_vendidos_loja1,
    'Loja2': Mais_vendidos_loja2,
    'Loja3': Mais_vendidos_loja3,
    'Loja4': Mais_vendidos_loja4})
df_Maiores_Vendas_combinado.round(2).sort_values(by='Loja', ascending=False)
# Out:
#                           Loja  Loja2  Loja3  Loja4
# Produto
# Guarda roupas             60.0    NaN    NaN    NaN
# TV Led UHD 4K             60.0    NaN    NaN    NaN
# Micro-ondas               60.0   62.0    NaN    NaN
# Secadora de roupas        58.0    NaN    NaN    NaN
# Blocos de montar          56.0    NaN    NaN    NaN
# Bateria                    NaN   61.0    NaN    NaN
# Cama box                   NaN    NaN    NaN   62.0
# Cama king                  NaN    NaN   56.0   56.0
# Cômoda                     NaN    NaN   55.0   55.0
# Dashboards com Power BI    NaN    NaN    NaN   56.0
# Faqueiro                   NaN    NaN    NaN   59.0
# Iniciando em programação   NaN   65.0    NaN    NaN
# Jogo de panelas            NaN    NaN   55.0    NaN
# Kit banquetas              NaN    NaN   57.0    NaN
# Mesa de jantar             NaN    NaN   56.0    NaN
# Pandeiro                   NaN   58.0    NaN    NaN
# Violão                     NaN   58.0    NaN    NaN

# %%
df_Menores_Vendas_combinado = pd.DataFrame({
    'Loja': Menos_vendidos_loja1,
    'Loja2': Menos_vendidos_loja2,
    'Loja3': Menos_vendidos_loja3,
    'Loja4': Menos_vendidos_loja4})
df_Menores_Vendas_combinado.round(2).sort_values(by='Loja', ascending=False)
# Out:
#                              Loja  Loja2  Loja3  Loja4
# Produto
# Ciência de dados com python  39.0    NaN    NaN    NaN
# Pandeiro                     36.0    NaN    NaN    NaN
# Panela de pressão            35.0    NaN    NaN    NaN
# Celular ABXY                 33.0    NaN    NaN    NaN
# Headset                      33.0    NaN    NaN    NaN
# Blocos de montar              NaN    NaN   35.0    NaN
# Copo térmico                  NaN    NaN   38.0    NaN
# Fone de ouvido                NaN   37.0    NaN    NaN
# Geladeira                     NaN    NaN    NaN   38.0
# Guarda roupas                 NaN    NaN    NaN   34.0
# Guitarra                      NaN    NaN    NaN   33.0
# Impressora                    NaN   34.0    NaN    NaN
# Jogo de copos                 NaN    NaN   36.0    NaN
# Jogo de tabuleiro             NaN   32.0    NaN    NaN
# Lavadora de roupas            NaN    NaN    NaN   38.0
# Mesa de jantar                NaN   34.0    NaN    NaN
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
loja.Frete
# Out:
# 0        9.249790
# 1       11.234305
# 2       21.262681
# 3       54.667344
# 4       26.964689
#           ...
# 2354    88.772042
# 2355    20.363958
# 2356     9.611337
# 2357    46.665919
# 2358    11.425995
# Name: Frete, Length: 2359, dtype: float64

# %%
media_frete_loja1 = loja['Frete'].mean().round(2)
#"Valor Médio Frete Loja 1"#
media_frete_loja1
# Out:
# np.float64(34.69)

# %%
media_frete_loja2 = loja2['Frete'].mean().round(2)
#"Valor Médio Frete Loja 2"#
media_frete_loja2
# Out:
# np.float64(33.62)

# %%
media_frete_loja3 = loja3['Frete'].mean().round(2)
#"Valor Médio Frete Loja 3"#
media_frete_loja3
# Out:
# np.float64(33.07)

# %%
media_frete_loja4 = loja4['Frete'].mean().round(2)
#"Valor Médio Frete Loja 4"#
media_frete_loja4
# Out:
# np.float64(31.28)

# %%
medias_frete_lojas = pd.DataFrame([media_frete_loja4,media_frete_loja3,media_frete_loja2,media_frete_loja1],columns=['Frete'],index=['Loja 1','Loja 2','Loja 3','Loja 4'])
medias_frete_lojas
#
# Out:
#         Frete
# Loja 1  31.28
# Loja 2  33.07
# Loja 3  33.62
# Loja 4  34.69

# %%
medias_frete_lojas.plot(kind='barh', figsize=(14,10), color='blue', title='Média de Frete por Loja', xlabel='Lojas', ylabel='Valor Médio do Frete')
#
# Out:
# <Axes: title={'center': 'Média de Frete por Loja'}, xlabel='Lojas', ylabel='Valor Médio do Frete'>

# %%
medias_frete_lojas.plot(kind='pie', y='Frete' ,figsize=(14,10), color='blue')
# Out:
# <Axes: ylabel='Frete'>

# %% [markdown]
# Baseado na análise dos dados das quatro lojas, levando em consideração as métricas que foram objetivo da análise de decisão, os dados mostram uma vantagem  de 2% em termos de faturamento para a loja 4 em relação a loja 1 que faturou menos. As quatro lojas possuem média de avaliação de clientes bem próxima a 4 com variação pequena entre elas sendo a pior avaliação da loja 4 e a melhor avaliação da loja 2 . As categorias de produtos mais vendidos são Móveis e eletrodomésticos nas quatro lojas. As categorias menos vendidas são Livros, Utilidades Domésticas e Instrumentos Musicais.
# Minha sugestão ao proprietário Sr. João é não vender nenhuma das lojas. Sugiro retirar as categorias Livros, Utilidades Domésticas e Instrumentos Musicais das lojas reduzindo o estoque e assim liberando recursos para novos investimentos.
